# %%
# cumsum returns cumulative sum over a dataframe or series axis.
import pandas as pd

# %%
# dataset is taken from Kaggle website (https://www.kaggle.com/saurabh00007/diabetescsv)
df = pd.read_csv('./datasets/diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# skipna: excludes NA/null values
df.cumsum(axis=0, skipna=True).head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          6.0    148.0           72.0           35.0      0.0   33.6
# 1          7.0    233.0          138.0           64.0      0.0   60.2
# 2         15.0    416.0          202.0           64.0      0.0   83.5
# 3         16.0    505.0          268.0           87.0     94.0  111.6
# 4         16.0    642.0          308.0          122.0    262.0  154.7
#
#    DiabetesPedigreeFunction    Age  Outcome
# 0                     0.627   50.0      1.0
# 1                     0.978   81.0      1.0
# 2                     1.650  113.0      2.0
# 3                     1.817  134.0      2.0
# 4                     4.105  167.0      3.0
