# %%
import pandas as pd

# %%
# dataset is taken from Kaggle website (https://www.kaggle.com)
df = pd.read_csv('./datasets/titanic.csv', index_col='PassengerId')

# %%
df.head(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# ...

# %%
sample = df.sample(n=100, replace=True)

# %%
sorted_sample = sample.sort_values(by=['PassengerId'])

# %%
sorted_sample
# Out:
#              Survived  Pclass  \
# PassengerId
# 7                   0       1
# 9                   1       3
# 20                  1       3
# 21                  0       2
# 25                  0       3
# 34                  0       2
# 55                  0       1
# 57                  1       2
# 62                  1       1
# 84                  0       1
# 88                  0       3
# 91                  0       3
# 92                  0       3
# 93                  0       1
# 99                  1       2
# 123                 0       2
# 141                 0       3
# 151                 0       2
# 162                 1       2
# 184                 1       2
# 194                 1       2
# 199                 1       3
# 204                 0       3
# 207                 0       3
# 231                 1       1
# 232                 0       3
# 236                 0       3
# 237                 0       2
# 240                 0       2
# ...
