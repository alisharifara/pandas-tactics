# %%
import pandas as pd
#Compute a simple cross tabulation of two (or more) factors.
#pandas.crosstab(index, columns, values=None, rownames=None, colnames=None, aggfunc=None, margins=False, 
               #margins_name='All', dropna=True, normalize=False)

# %%
# dataset is taken from Kaggle website (https://www.kaggle.com)
df = pd.read_csv('./datasets/titanic.csv', index_col='PassengerId')

# %%
df.head(5)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
pd.crosstab(df["Name"],df["Pclass"], margins=True)
# Out:
# Pclass                                             1    2    3  All
# Name
# Abbing, Mr. Anthony                                0    0    1    1
# Abbott, Mr. Rossmore Edward                        0    0    1    1
# Abbott, Mrs. Stanton (Rosa Hunt)                   0    0    1    1
# Abelson, Mr. Samuel                                0    1    0    1
# Abelson, Mrs. Samuel (Hannah Wizosky)              0    1    0    1
# Adahl, Mr. Mauritz Nils Martin                     0    0    1    1
# Adams, Mr. John                                    0    0    1    1
# Ahlin, Mrs. Johan (Johanna Persdotter Larsson)     0    0    1    1
# Aks, Mrs. Sam (Leah Rosen)                         0    0    1    1
# Albimona, Mr. Nassef Cassem                        0    0    1    1
# Alexander, Mr. William                             0    0    1    1
# Alhomaki, Mr. Ilmari Rudolf                        0    0    1    1
# Ali, Mr. Ahmed                                     0    0    1    1
# ...
